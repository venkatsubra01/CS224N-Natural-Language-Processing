# %%
# !pip install patool
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.5/86.5 kB 8.2 MB/s eta 0:00:00
# ...

# %%
import patoolib

# %%
ret = patoolib.extract_archive("a4.zip", outdir="./extracted_a4_2")
# Out:
# INFO patool: Extracting a4.zip ...
# INFO:patool:Extracting a4.zip ...
# INFO patool: ... creating output directory `./extracted_a4_2'.
# INFO:patool:... creating output directory `./extracted_a4_2'.
# INFO patool: running /usr/bin/7z x -aou -o./extracted_a4_2 -- a4.zip
# INFO:patool:running /usr/bin/7z x -aou -o./extracted_a4_2 -- a4.zip
# INFO patool: ... a4.zip extracted to `./extracted_a4_2'.
# INFO:patool:... a4.zip extracted to `./extracted_a4_2'.

# %%
print(f"ret: {ret}")
# Out:
# ret: ./extracted_a4_2

# %%
# %cd ..
# Out:
# /content

# %%
# %cd extracted_a4_2
# %cd student
# !pip install -r gpu_requirements.txt
# Out:
# /content/extracted_a4_2
# /content/extracted_a4_2/student
# ...

# %%
# !sh run.sh train
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# 2025-06-25 15:52:15.264604: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750866735.284850   16557 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750866735.290941   16557 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-25 15:52:15.312773: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %%
# !sh run.sh test
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# 2025-06-25 16:43:10.057124: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750869790.078671   35014 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750869790.084870   35014 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-25 16:43:10.104511: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...
